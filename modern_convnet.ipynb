# %% [markdown]
# ### Raniery Mendes
# #### Exploring Modern Practices in ConvNets

# %%
#imports
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import os, shutil, pathlib
from tensorflow.keras.utils import image_dataset_from_directory

# %% [markdown]
# Residual Connections add the layer's input to output from that layer.

# %%
inputs = keras.Input(shape=(32, 32, 3))
x = layers.Conv2D(32, 3, activation="relu")(inputs)
residual = x
x = layers.Conv2D(64, 3, activation="relu", padding="same")(x)
residual = layers.Conv2D(64, 1)(residual)
x = layers.add([x, residual])

# %%
inputs = keras.Input(shape=(32, 32, 3))
x = layers.Conv2D(32, 3, activation="relu")(inputs)
residual = x
x = layers.Conv2D(64, 3, activation="relu", padding="same")(x)
x = layers.MaxPooling2D(2, padding="same")(x)
residual = layers.Conv2D(64, 1, strides=2)(residual)
x = layers.add([x, residual])

# %%
inputs = keras.Input(shape=(32, 32, 3))
x = layers.Rescaling(1./255)(inputs)

def residual_block(x, filters, pooling=False):
    residual = x
    x = layers.Conv2D(filters, 3, activation="relu", padding="same")(x)
    x = layers.Conv2D(filters, 3, activation="relu", padding="same")(x)
    if pooling:
        x = layers.MaxPooling2D(2, padding="same")(x)
        residual = layers.Conv2D(filters, 1, strides=2)(residual)
    elif filters != residual.shape[-1]:
        residual = layers.Conv2D(filters, 1)(residual)
    x = layers.add([x, residual])
    return x

x = residual_block(x, filters=32, pooling=True)
x = residual_block(x, filters=64, pooling=True)
x = residual_block(x, filters=128, pooling=False)

x = layers.GlobalAveragePooling2D()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 32, 32, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling           │ (None, 32, 32, 3) │          0 │ input_layer_2[0]… │
# │ (Rescaling)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │        896 │ rescaling[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │      9,248 │ conv2d_6[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 16, 16,    │          0 │ conv2d_7[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 16, 16,    │        128 │ rescaling[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 16, 16,    │          0 │ max_pooling2d_1[… │
# │                     │ 32)               │            │ conv2d_8[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 16, 16,    │     18,496 │ add_2[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 16, 16,    │     36,928 │ conv2d_9[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 8, 8, 64)  │          0 │ conv2d_10[0][0]   │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 8, 8, 64)  │      2,112 │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 8, 8, 64)  │          0 │ max_pooling2d_2[… │
# │                     │                   │            │ conv2d_11[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 8, 8, 128) │     73,856 │ add_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 8, 8, 128) │    147,584 │ conv2d_12[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 8, 8, 128) │      8,320 │ add_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 8, 8, 128) │          0 │ conv2d_13[0][0],  │
# │                     │                   │            │ conv2d_14[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ add_4[0][0]       │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 1)         │        129 │ global_average_p… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 297,697 (1.14 MB)
#  Trainable params: 297,697 (1.14 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
new_base_dir = pathlib.Path("./")
train_dataset = image_dataset_from_directory(f"{new_base_dir}/train", image_size=(180, 180), batch_size=32)
validation_dataset = image_dataset_from_directory(f"{new_base_dir}/validation", image_size=(180, 180),batch_size=32)
test_dataset = image_dataset_from_directory(f"{new_base_dir}/test",image_size=(180, 180), batch_size=32)
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# Found 2000 files belonging to 2 classes.

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
    ]
)

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)

x = layers.Rescaling(1./255)(x)
x = layers.Conv2D(filters=32, kernel_size=5, use_bias=False)(x)

for size in [32, 64, 128, 256, 512]:
    residual = x

    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.SeparableConv2D(size, 3, padding="same", use_bias=False)(x)

    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.SeparableConv2D(size, 3, padding="same", use_bias=False)(x)

    x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

    residual = layers.Conv2D(
        size, 1, strides=2, padding="same", use_bias=False)(residual)
    x = layers.add([x, residual])

x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])
history = model.fit(
    train_dataset,
    epochs=100,
    validation_data=validation_dataset)
# Out:
# Epoch 1/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.5436 - loss: 0.7726 - val_accuracy: 0.5000 - val_loss: 0.7011
# Epoch 2/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - accuracy: 0.5799 - loss: 0.6732 - val_accuracy: 0.5000 - val_loss: 0.6965
# Epoch 3/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 93s 1s/step - accuracy: 0.6116 - loss: 0.6474 - val_accuracy: 0.5000 - val_loss: 0.7069
# Epoch 4/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.6577 - loss: 0.6266 - val_accuracy: 0.5000 - val_loss: 0.7206
# Epoch 5/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 103s 2s/step - accuracy: 0.6497 - loss: 0.6391 - val_accuracy: 0.5000 - val_loss: 0.7013
# Epoch 6/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 125s 2s/step - accuracy: 0.6834 - loss: 0.6114 - val_accuracy: 0.5000 - val_loss: 0.7527
# Epoch 7/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 114s 2s/step - accuracy: 0.6704 - loss: 0.5952 - val_accuracy: 0.5050 - val_loss: 0.7587
# Epoch 8/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - accuracy: 0.7013 - loss: 0.5830 - val_accuracy: 0.5210 - val_loss: 0.9106
# Epoch 9/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 108s 2s/step - accuracy: 0.7122 - loss: 0.5725 - val_accuracy: 0.7290 - val_loss: 0.5422
# Epoch 10/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 100s 2s/step - accuracy: 0.7241 - loss: 0.5570 - val_accuracy: 0.6620 - val_loss: 0.6300
# Epoch 11/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 106s 2s/step - accuracy: 0.7257 - loss: 0.5434 - val_accuracy: 0.7210 - val_loss: 0.5636
# Epoch 12/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.7599 - loss: 0.5190 - val_accuracy: 0.5420 - val_loss: 1.2754
# Epoch 13/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.7490 - loss: 0.4938 - val_accuracy: 0.6090 - val_loss: 1.0999
# Epoch 14/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.7643 - loss: 0.4966 - val_accuracy: 0.6020 - val_loss: 1.1042
# Epoch 15/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.7710 - loss: 0.4909 - val_accuracy: 0.5690 - val_loss: 1.2454
# Epoch 16/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.7841 - loss: 0.4764 - val_accuracy: 0.5410 - val_loss: 1.1843
# Epoch 17/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.7831 - loss: 0.4651 - val_accuracy: 0.6690 - val_loss: 0.7842
# Epoch 18/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.7944 - loss: 0.4432 - val_accuracy: 0.5170 - val_loss: 2.2463
# Epoch 19/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.8026 - loss: 0.4323 - val_accuracy: 0.7600 - val_loss: 0.4720
# Epoch 20/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.8085 - loss: 0.4361 - val_accuracy: 0.7550 - val_loss: 0.5075
# Epoch 21/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.8059 - loss: 0.4350 - val_accuracy: 0.6460 - val_loss: 0.8985
# Epoch 22/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.7884 - loss: 0.4388 - val_accuracy: 0.5120 - val_loss: 1.9390
# Epoch 23/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.8370 - loss: 0.3948 - val_accuracy: 0.7920 - val_loss: 0.4970
# Epoch 24/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.8328 - loss: 0.3975 - val_accuracy: 0.7100 - val_loss: 0.6787
# Epoch 25/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.8110 - loss: 0.4023 - val_accuracy: 0.6120 - val_loss: 1.7087
# Epoch 26/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.8301 - loss: 0.3781 - val_accuracy: 0.7980 - val_loss: 0.4955
# Epoch 27/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.8446 - loss: 0.3647 - val_accuracy: 0.7900 - val_loss: 0.4470
# Epoch 28/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 87s 1s/step - accuracy: 0.8483 - loss: 0.3420 - val_accuracy: 0.7140 - val_loss: 0.7234
# Epoch 29/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 89s 1s/step - accuracy: 0.8419 - loss: 0.3578 - val_accuracy: 0.7930 - val_loss: 0.4557
# Epoch 30/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 89s 1s/step - accuracy: 0.8517 - loss: 0.3274 - val_accuracy: 0.8090 - val_loss: 0.5367
# Epoch 31/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 87s 1s/step - accuracy: 0.8418 - loss: 0.3238 - val_accuracy: 0.7820 - val_loss: 0.5444
# Epoch 32/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 87s 1s/step - accuracy: 0.8537 - loss: 0.3221 - val_accuracy: 0.6130 - val_loss: 1.2337
# Epoch 33/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.8675 - loss: 0.3204 - val_accuracy: 0.8090 - val_loss: 0.4668
# Epoch 34/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 89s 1s/step - accuracy: 0.8730 - loss: 0.3083 - val_accuracy: 0.7090 - val_loss: 1.0323
# Epoch 35/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.8757 - loss: 0.2955 - val_accuracy: 0.7790 - val_loss: 0.6753
# Epoch 36/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.8841 - loss: 0.2812 - val_accuracy: 0.8150 - val_loss: 0.4836
# Epoch 37/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.8745 - loss: 0.2904 - val_accuracy: 0.7580 - val_loss: 0.5846
# Epoch 38/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.8782 - loss: 0.2905 - val_accuracy: 0.8240 - val_loss: 0.4177
# Epoch 39/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.8774 - loss: 0.3117 - val_accuracy: 0.8260 - val_loss: 0.4238
# Epoch 40/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.8920 - loss: 0.2868 - val_accuracy: 0.7590 - val_loss: 0.5625
# Epoch 41/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.8942 - loss: 0.2483 - val_accuracy: 0.8360 - val_loss: 0.4536
# Epoch 42/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.8713 - loss: 0.2725 - val_accuracy: 0.8260 - val_loss: 0.4240
# Epoch 43/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.8900 - loss: 0.2610 - val_accuracy: 0.8390 - val_loss: 0.4008
# Epoch 44/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.8932 - loss: 0.2747 - val_accuracy: 0.8530 - val_loss: 0.3415
# Epoch 45/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.8933 - loss: 0.2348 - val_accuracy: 0.8460 - val_loss: 0.3706
# Epoch 46/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9067 - loss: 0.2286 - val_accuracy: 0.8610 - val_loss: 0.3711
# Epoch 47/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.8801 - loss: 0.2604 - val_accuracy: 0.8090 - val_loss: 0.6097
# Epoch 48/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9075 - loss: 0.2244 - val_accuracy: 0.6360 - val_loss: 1.2661
# Epoch 49/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.8924 - loss: 0.2562 - val_accuracy: 0.8520 - val_loss: 0.3890
# Epoch 50/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 99s 2s/step - accuracy: 0.9008 - loss: 0.2197 - val_accuracy: 0.8630 - val_loss: 0.4069
# Epoch 51/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 110s 2s/step - accuracy: 0.9041 - loss: 0.2214 - val_accuracy: 0.8660 - val_loss: 0.3686
# Epoch 52/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 99s 2s/step - accuracy: 0.9060 - loss: 0.2294 - val_accuracy: 0.7280 - val_loss: 0.9255
# Epoch 53/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.8948 - loss: 0.2413 - val_accuracy: 0.7550 - val_loss: 0.7460
# Epoch 54/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 93s 1s/step - accuracy: 0.9109 - loss: 0.2413 - val_accuracy: 0.8820 - val_loss: 0.3235
# Epoch 55/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - accuracy: 0.9018 - loss: 0.2206 - val_accuracy: 0.7950 - val_loss: 0.5293
# Epoch 56/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 95s 2s/step - accuracy: 0.9034 - loss: 0.2418 - val_accuracy: 0.8060 - val_loss: 0.5770
# Epoch 57/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 98s 2s/step - accuracy: 0.9222 - loss: 0.1809 - val_accuracy: 0.8090 - val_loss: 0.7311
# Epoch 58/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.9245 - loss: 0.2139 - val_accuracy: 0.8600 - val_loss: 0.3878
# Epoch 59/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 129s 2s/step - accuracy: 0.9403 - loss: 0.1598 - val_accuracy: 0.8800 - val_loss: 0.3693
# Epoch 60/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 116s 2s/step - accuracy: 0.9133 - loss: 0.2081 - val_accuracy: 0.7910 - val_loss: 0.7413
# Epoch 61/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 111s 2s/step - accuracy: 0.9055 - loss: 0.2178 - val_accuracy: 0.8680 - val_loss: 0.3645
# Epoch 62/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1006s 16s/step - accuracy: 0.9286 - loss: 0.1831 - val_accuracy: 0.8670 - val_loss: 0.3676
# Epoch 63/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - accuracy: 0.9303 - loss: 0.1683 - val_accuracy: 0.7980 - val_loss: 0.7817
# Epoch 64/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.9352 - loss: 0.1713 - val_accuracy: 0.8550 - val_loss: 0.4700
# Epoch 65/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 89s 1s/step - accuracy: 0.9253 - loss: 0.1922 - val_accuracy: 0.7690 - val_loss: 1.0859
# Epoch 66/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 94s 1s/step - accuracy: 0.9205 - loss: 0.1892 - val_accuracy: 0.7970 - val_loss: 0.6073
# Epoch 67/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 89s 1s/step - accuracy: 0.9297 - loss: 0.1761 - val_accuracy: 0.6650 - val_loss: 1.9789
# Epoch 68/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 89s 1s/step - accuracy: 0.9388 - loss: 0.1525 - val_accuracy: 0.8080 - val_loss: 0.6985
# Epoch 69/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.9436 - loss: 0.1503 - val_accuracy: 0.8250 - val_loss: 0.5181
# Epoch 70/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 988s 16s/step - accuracy: 0.9267 - loss: 0.1833 - val_accuracy: 0.8830 - val_loss: 0.3698
# Epoch 71/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 975s 16s/step - accuracy: 0.9326 - loss: 0.1773 - val_accuracy: 0.7640 - val_loss: 1.1320
# Epoch 72/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - accuracy: 0.9325 - loss: 0.1580 - val_accuracy: 0.8410 - val_loss: 0.5431
# Epoch 73/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.9429 - loss: 0.1435 - val_accuracy: 0.8490 - val_loss: 0.3583
# Epoch 74/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 86s 1s/step - accuracy: 0.9304 - loss: 0.1685 - val_accuracy: 0.7790 - val_loss: 0.7426
# Epoch 75/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 980s 16s/step - accuracy: 0.9471 - loss: 0.1545 - val_accuracy: 0.7730 - val_loss: 0.6814
# Epoch 76/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 980s 16s/step - accuracy: 0.9352 - loss: 0.1696 - val_accuracy: 0.7820 - val_loss: 0.7555
# Epoch 77/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9372 - loss: 0.1635 - val_accuracy: 0.8630 - val_loss: 0.4154
# Epoch 78/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9457 - loss: 0.1331 - val_accuracy: 0.8800 - val_loss: 0.3182
# Epoch 79/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9446 - loss: 0.1498 - val_accuracy: 0.8830 - val_loss: 0.4031
# Epoch 80/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.9466 - loss: 0.1285 - val_accuracy: 0.8210 - val_loss: 0.7960
# Epoch 81/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 85s 1s/step - accuracy: 0.9512 - loss: 0.1318 - val_accuracy: 0.8420 - val_loss: 0.6829
# Epoch 82/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 86s 1s/step - accuracy: 0.9584 - loss: 0.1055 - val_accuracy: 0.8900 - val_loss: 0.3341
# Epoch 83/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 87s 1s/step - accuracy: 0.9406 - loss: 0.1546 - val_accuracy: 0.8510 - val_loss: 0.4695
# Epoch 84/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.9495 - loss: 0.1288 - val_accuracy: 0.8190 - val_loss: 0.4885
# Epoch 85/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.9404 - loss: 0.1412 - val_accuracy: 0.8620 - val_loss: 0.4852
# Epoch 86/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1068s 17s/step - accuracy: 0.9611 - loss: 0.1138 - val_accuracy: 0.7880 - val_loss: 0.8074
# Epoch 87/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1111s 18s/step - accuracy: 0.9535 - loss: 0.1211 - val_accuracy: 0.7620 - val_loss: 1.1372
# Epoch 88/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.9503 - loss: 0.1269 - val_accuracy: 0.8430 - val_loss: 0.6244
# Epoch 89/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9416 - loss: 0.1376 - val_accuracy: 0.8770 - val_loss: 0.3410
# Epoch 90/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.9461 - loss: 0.1236 - val_accuracy: 0.8470 - val_loss: 0.5811
# Epoch 91/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 86s 1s/step - accuracy: 0.9321 - loss: 0.1665 - val_accuracy: 0.7840 - val_loss: 0.8356
# Epoch 92/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 87s 1s/step - accuracy: 0.9518 - loss: 0.1158 - val_accuracy: 0.8350 - val_loss: 0.7728
# Epoch 93/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 87s 1s/step - accuracy: 0.9356 - loss: 0.1540 - val_accuracy: 0.8780 - val_loss: 0.3453
# Epoch 94/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 94s 1s/step - accuracy: 0.9554 - loss: 0.1144 - val_accuracy: 0.8980 - val_loss: 0.3686
# Epoch 95/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.9420 - loss: 0.1392 - val_accuracy: 0.8880 - val_loss: 0.4050
# Epoch 96/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.9496 - loss: 0.1209 - val_accuracy: 0.8430 - val_loss: 0.7082
# Epoch 97/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1128s 18s/step - accuracy: 0.9571 - loss: 0.1027 - val_accuracy: 0.8870 - val_loss: 0.3442
# Epoch 98/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1088s 18s/step - accuracy: 0.9476 - loss: 0.1230 - val_accuracy: 0.8840 - val_loss: 0.4597
# Epoch 99/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9482 - loss: 0.1225 - val_accuracy: 0.8550 - val_loss: 0.5505
# Epoch 100/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - accuracy: 0.9471 - loss: 0.1258 - val_accuracy: 0.9100 - val_loss: 0.3240

# %%
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.figure(figsize=(5.5,4))
plt.plot(epochs, accuracy, "ro", label="Training accuracy") 
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy") 
plt.title("Training and validation accuracy")
plt.legend()
plt.savefig("train_val_accuracy.png", format="png")
plt.figure(figsize=(5.5,4))
plt.plot(epochs, loss, "ro", label="Training loss") 
plt.plot(epochs, val_loss, "b", label="Validation loss") 
plt.title("Training and validation loss")
plt.legend()
plt.show()
plt.savefig("train_val_loss.png", format="png")
